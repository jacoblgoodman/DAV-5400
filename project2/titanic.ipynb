# %% [markdown]
# # part 1: Introduction:
# For this project I choose to utilize version of the famous titanic data set.
#
# # part 2 data Summary:
# is data set is a dirivitative kaggles famous titanic data set augumented with infomration from wikipedia.
# It was also hosted on kaggl.com at https://www.kaggle.com/pavlofesenko/titanic-extended/version/2

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('full.csv',)

# %%
display(df.head())

df.columns

df.describe()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare  ...  Embarked WikiId  \
# 0      0         A/5 21171   7.2500  ...         S  691.0
# 1      0          PC 17599  71.2833  ...         C   90.0
# 2      0  STON/O2. 3101282   7.9250  ...         S  865.0
# 3      0            113803  53.1000  ...         S  127.0
# ...
